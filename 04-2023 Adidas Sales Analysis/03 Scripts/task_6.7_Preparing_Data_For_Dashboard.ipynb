# %%
#import libraries
import pandas as pd
import numpy as np
import os
import datetime as dt

# %%
#Create path
path = r'/Users/rusamijan/04-2023 Adidas Sales Analysis'

# %%
#Import data
df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ad_cleaned.pkl'))

# %%
df.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732       1/1/20  Northeast  New York  New York
# 1  Foot Locker      1185732       1/2/20  Northeast  New York  New York
# 2  Foot Locker      1185732       1/3/20  Northeast  New York  New York
# 3  Foot Locker      1185732       1/4/20  Northeast  New York  New York
# 4  Foot Locker      1185732       1/5/20  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0      1200.0     600000.0
# 1    Men's Athletic Footwear            50.0      1000.0     500000.0
# 2    Women's Street Footwear            40.0      1000.0     400000.0
# 3  Women's Athletic Footwear            45.0       850.0     382500.0
# 4              Men's Apparel            60.0       900.0     540000.0
#
#    Operating Profit Operating Margin Sales Method
# 0          300000.0              50%     In-store
# ...

# %%
df.shape
# Out:
# (9648, 13)

# %%
# Removing columns that we don't use for analysis
df1=df.drop(['Retailer', 'Retailer ID', 'Operating Margin'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#   Invoice Date     Region     State      City                    Product  \
# 0       1/1/20  Northeast  New York  New York      Men's Street Footwear
# 1       1/2/20  Northeast  New York  New York    Men's Athletic Footwear
# 2       1/3/20  Northeast  New York  New York    Women's Street Footwear
# 3       1/4/20  Northeast  New York  New York  Women's Athletic Footwear
# 4       1/5/20  Northeast  New York  New York              Men's Apparel
#
#    Price per Unit  Units Sold  Total Sales  Operating Profit Sales Method
# 0            50.0      1200.0     600000.0          300000.0     In-store
# 1            50.0      1000.0     500000.0          150000.0     In-store
# 2            40.0      1000.0     400000.0          140000.0     In-store
# 3            45.0       850.0     382500.0          133875.0     In-store
# 4            60.0       900.0     540000.0          162000.0     In-store

# %%
df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'adidas_4analysis.csv'))
